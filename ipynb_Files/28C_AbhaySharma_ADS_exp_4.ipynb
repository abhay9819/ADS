# %% [markdown]
# **Name: Abhay Sharma**
#
# **Class: BE - C**
#
# **Moodle Id: 20102065**
#
# **Roll No.: 28**
#
# **Sub.: Applied Data Science**

# %% [markdown]
# **<h1 align=center>Experiment No.: 04</h1>**

# %% [markdown]
# **Aim: To explore the data visualization techniques.**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings

# %% [markdown]
# **Loading the dataset**

# %%
tips = sns.load_dataset('tips')
df = pd.DataFrame(tips)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **Preprocessing and Exploratory data analysis**

# %% [markdown]
# **Checking for missing values**

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# **Viewing the descriptive statistics of the dataset**

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# **Get a numerical summary for 'tip'**

# %%
df.tip.describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %% [markdown]
# **Summary for 'bill' and 'tip'**

# %%
bill = df.total_bill

print("Maximum Bill: ", np.max(bill))
print("Minimum Bill: ", np.min(bill))
print("Standard Deviation: ", np.std(bill))
print("Median: ", np.median(bill))
print("Mean: ", np.mean(bill))
# Out:
# Maximum Bill:  50.81
# Minimum Bill:  3.07
# Standard Deviation:  8.884150577771132
# Median:  17.795
# Mean:  19.78594262295082

# %%
tip = df.tip

print("Maximum tip: ", np.max(tip))
print("Minimum tip: ", np.min(tip))
print("Standard Deviation: ", np.std(tip))
print("Median: ", np.median(tip))
print("Mean: ", np.mean(tip))
# Out:
# Maximum tip:  10.0
# Minimum tip:  1.0
# Standard Deviation:  1.3807999538298954
# Median:  2.9
# Mean:  2.99827868852459

# %% [markdown]
# **Exploratory Data analysis**

# %% [markdown]
# **Explore if there is any dependency between the variable 'tip' and rest of the variable**

# %%
sns.countplot(x = 'sex', data = tips)
sns.despine() # no top and right axes spine

print(tips.sex.value_counts())
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# **Inference: Male customers paid more number of tips than Female**

# %%
sns.countplot(x = 'sex', data = tips, hue = 'smoker', palette = 'viridis')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# **Inference: More number of tips have been paid by non smoker male and female.**

# %%
plt.figure(figsize = (8,6))
plt.title("Tips per day of week")
sns.countplot(x = tips['day'], color = 'purple')
# Out:
# <Axes: title={'center': 'Tips per day of week'}, xlabel='day', ylabel='count'>

# %% [markdown]
# **Inference: More number of tips are paid on weekends i.e. on saturday and sunday.**

# %%
sns.catplot(x = 'day', data = tips, hue = 'sex', palette = 'ch:.25', kind = 'count')

# %% [markdown]
# **Inference: On weekends Male customers paid more number of tips than female.**

# %%
sns.displot(df['tip'], kde = 'true')

# %% [markdown]
# **Inference: More tips are paid in range of $2 to $4 and there are some Outliers.**

# %%
g = sns.distplot(tips.tip,kde = False)
g.set_title("Tip amount Histogram")
# Out:
# <ipython-input-15-c9959e0b8632>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   g = sns.distplot(tips.tip,kde = False)
# Text(0.5, 1.0, 'Tip amount Histogram')

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=bill,color="c")
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# Result : Majority Range=(15,25)
#
# outliers = upto 55

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x=tip,color="g")
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# Result : Majority Range=(2,4)
#
# outliers = upto 10

# %%
sns.relplot(x = "total_bill", y = 'tip', data=df,col = 'time', hue='smoker',size='size')

# %% [markdown]
# Result:
# 1. lunch time: less tips / Dinner time: More tips
# 2. more bill amount : Bigger tip
# 3. Non Smoker pay more tips

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x = "total_bill", y = 'tip', data=df, hue='sex');

# %% [markdown]
# Result:
#
# Male Pay more tips
#
# as amount increases tip incresases

# %%
sns.lmplot(x = "total_bill", y = 'tip', data=df,col = 'time', hue='smoker')

# %% [markdown]
# Result:
# 1. lunch time: less tips / Dinner time: More tips
# 2. more bill amount : Bigger tip
# 3. Non Smoker pay more tips

# %%
sns.catplot(x="day",y="tip",data=df,kind="swarm")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Result:
#
# More tips on saturday and sunday
#
# Highest on Saturday

# %%
sns.catplot(x="day",y="tip",data=df,kind="bar",palette ='muted',height=6)
# Out:
# <ipython-input-34-6aef28c82619>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="day",y="tip",data=df,kind="bar",palette ='muted',height=6)

# %%
sns.catplot(x="day",y="tip",data=df,kind="violin")

# %%
sns.pairplot(df,hue='sex')

# %%
corr_matrix = df.corr()
ax=sns.heatmap(data=corr_matrix,annot=True,vmax=1,vmin=-1,center=0)
# Out:
# <ipython-input-42-b103e1d85f2e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_df= LabelEncoder()
df['sex']=labelencoder_df.fit_transform(df['sex'])
df['smoker']=labelencoder_df.fit_transform(df['smoker'])
df['day']=labelencoder_df.fit_transform(df['day'])
df['time']=labelencoder_df.fit_transform(df['time'])
df.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
corr_matrix = df.corr()
ax=sns.heatmap(data=corr_matrix,annot=True,vmax=1,vmin=-1,center=0)

# %% [markdown]
# Result:
# 1. highest Corelation : total bill and tip
#
# 2. lowest corelation : smoker and day

# %% [markdown]
# Conclusion:
#
#
# Data visualization is done on the tips dataset of Seaborn using plots for different types of variables and inferences are made about the relationship between total bill, tip, day, time,
# gender, smoker or non-smoker etc.
